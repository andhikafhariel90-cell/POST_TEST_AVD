# %% [markdown]
# Nama : Andhika Fhariel Fadhlurrohman
#
# NIM : 2509116083
#
# Kelas C 2025

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file = '/content/consumer_electronics_sales_data.csv'

df = pd.read_csv(file)
df
# Out:
#       ProductID ProductCategory  ProductBrand  ProductPrice  CustomerAge  \
# 0          5874     Smartphones  Other Brands    312.949668           18
# 1          5875   Smart Watches       Samsung    980.389404           35
# 2          5876         Tablets       Samsung   2606.718293           63
# 3          5877     Smartphones       Samsung    870.395450           63
# 4          5878         Tablets          Sony   1798.955875           57
# ...         ...             ...           ...           ...          ...
# 8995      14869   Smart Watches       Samsung   1041.149163           36
# 8996      14870     Smartphones       Samsung   1485.694311           57
# 8997      14871      Headphones       Samsung   2887.369597           28
# 8998      14872         Tablets            HP   1490.453964           38
# 8999      14873     Smartphones          Sony   2315.583087           62
#
#       CustomerGender  PurchaseFrequency  CustomerSatisfaction  PurchaseIntent
# ...

# %% [markdown]
# # **Business Understanding**

# %% [markdown]
# Pasar elektronik konsumen sangat kompetitif dengan siklus hidup produk yang pendek. Perusahaan ritel sering kali memiliki data transaksi yang besar namun kesulitan untuk memahami siapa pelanggan mereka sebenarnya dan produk apa yang paling menguntungkan. Tanpa pemahaman ini, strategi pemasaran dan stok barang sering kali tidak tepat sasaran.

# %% [markdown]
# ## **Business Objective**

# %% [markdown]
#  Tujuan utama dari inisiatif bisnis ini adalah untuk memacu pertumbuhan pendapatan melalui strategi berbasis data yang komprehensif. Dengan mengidentifikasi faktor penentu total belanja pelanggan, perusahaan dapat secara efektif meningkatkan volume penjualan sekaligus mengoptimalkan personalisasi pemasaran melalui pemetaan preferensi produk—seperti Laptop, Smartphone, dan TV berdasarkan demografi umur serta gender. Selain itu, analisis ini bertujuan untuk mencapai efisiensi operasional melalui optimalisasi inventaris yang presisi, yang didasarkan pada pemahaman mendalam mengenai pola waktu puncak pembelian dan tingkat perputaran produk yang paling diminati di pasar.

# %% [markdown]
# ## **Asses Situasion**

# %% [markdown]
# Analisis ini memanfaatkan dataset komprehensif yang mencakup profil pelanggan (ID, umur, gender), detail transaksi (kategori produk, kuantitas, harga), serta data penilaian produk untuk mengukur kepuasan konsumen. Meskipun proses identifikasi tren dibatasi oleh anonimitas data yang meniadakan variabel lokasi geografis, seluruh pengolahan dan pemodelan dilakukan secara efisien menggunakan ekosistem Python khususnya pustaka Pandas, Matplotlib, dan Scikit Learn di dalam lingkungan kerja Google Colab yang kolaboratif.

# %% [markdown]
# ## **Analytic Goals**

# %% [markdown]
# Proses analisis data ini dilakukan secara bertahap, dimulai dari Analisis Deskriptif untuk memetakan performa produk unggulan, profil demografi target pasar, serta tren musiman guna menangkap dinamika penjualan historis. Langkah ini diperdalam melalui Analisis Diagnostik yang mengevaluasi elastisitas harga terhadap kuantitas penjualan serta korelasi kategori produk dengan tingkat kepuasan pelanggan untuk mengidentifikasi akar permasalahan performa pasar. Untuk memitigasi risiko masa depan, Analisis Prediktif diterapkan menggunakan model regresi dan klasifikasi untuk memproyeksikan nilai transaksi serta perilaku pembelian pelanggan baru. Seluruh temuan tersebut kemudian dikonversi menjadi strategi konkret dalam Analisis Preskriptif, yang mencakup rekomendasi bundling produk yang sinergis serta optimasi kebijakan diskon yang presisi untuk menstimulasi kategori produk dengan perputaran rendah.

# %% [markdown]
# ## **Project Plan**

# %% [markdown]
# # **Data Understanding**

# %% [markdown]
# ##Memuat Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')

path = '/content/drive/MyDrive/Check point AVD/consumer_electronics_sales_data.csv'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
df = pd.read_csv(path)
df
# Out:
#       ProductID ProductCategory  ProductBrand  ProductPrice  CustomerAge  \
# 0          5874     Smartphones  Other Brands    312.949668           18
# 1          5875   Smart Watches       Samsung    980.389404           35
# 2          5876         Tablets       Samsung   2606.718293           63
# 3          5877     Smartphones       Samsung    870.395450           63
# 4          5878         Tablets          Sony   1798.955875           57
# ...         ...             ...           ...           ...          ...
# 8995      14869   Smart Watches       Samsung   1041.149163           36
# 8996      14870     Smartphones       Samsung   1485.694311           57
# 8997      14871      Headphones       Samsung   2887.369597           28
# 8998      14872         Tablets            HP   1490.453964           38
# 8999      14873     Smartphones          Sony   2315.583087           62
#
#       CustomerGender  PurchaseFrequency  CustomerSatisfaction  PurchaseIntent
# ...

# %% [markdown]
# Alur kerja proyek ini dimulai dengan tahap Data Preparation untuk menjamin kualitas analisis melalui pembersihan nilai yang hilang dan melakukan encoding pada variabel kategori seperti gender dan kategori produk. Selanjutnya, dilakukan Exploratory Data Analysis (EDA) untuk memvisualisasikan distribusi demografi, tren penjualan periodik, serta komparasi performa antarproduk guna menangkap pola perilaku pasar yang signifikan. Pada tahap Modeling, algoritma Machine Learning seperti Random Forest atau Linear Regression diterapkan dan hasilnya akan diuji melalui tahap Evaluation menggunakan metrik MSE atau R2 Score untuk memastikan akurasi prediksi. Seluruh rangkaian ini diakhiri dengan tahap Deployment/Reporting, di mana temuan teknis dikonversi menjadi insight strategis yang siap dipresentasikan kepada tim manajemen untuk pengambilan keputusan bisnis yang tepat.

# %% [markdown]
# ##**Deskripsi Data**

# %% [markdown]
# ### **Struktur Data ( Informasi Lanjutan )**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9000 entries, 0 to 8999
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ProductID             9000 non-null   int64
#  1   ProductCategory       9000 non-null   object
#  2   ProductBrand          9000 non-null   object
#  3   ProductPrice          9000 non-null   float64
#  4   CustomerAge           9000 non-null   int64
#  5   CustomerGender        9000 non-null   int64
#  6   PurchaseFrequency     9000 non-null   int64
#  7   CustomerSatisfaction  9000 non-null   int64
#  8   PurchaseIntent        9000 non-null   int64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 632.9+ KB

# %% [markdown]
# 1. ProductID: Jumlah baris: 9000 Tipe data: int64 Deskripsi: ID Unik Produk
# 2. ProductCategory: Jumlah baris: 9000 Tipe data: object Deskripsi: Kategori Produk
# 3. ProductBrand: Jumlah baris: 9000 Tipe data: object Deskripsi: Merek Produk
# 4. ProductPrice: Jumlah baris: 9000 Tipe data: float64 Deskripsi: Harga Produk
# 5. CustomerAge: Jumlah baris: 9000 Tipe data: int64 Deskripsi: Usia Pelanggan
# 6. CustomerGender: Jumlah baris: 9000 Tipe data: int64 Deskripsi: Jenis Kelamin Pelanggan
# 7. PurchaseFrequency: Jumlah baris: 9000 Tipe data: int64 Deskripsi: Frekuensi Pembelian
# 8. CustomerSatisfaction: Jumlah baris: 9000 Tipe data: int64 Deskripsi: Tingkat Kepuasan Pelanggan
# 9. PurchaseIntent: Jumlah baris: 9000 Tipe data: int64 Deskripsi: Niat Membeli Pelanggan (Target)

# %% [markdown]
# ### **Informasi Statistik Deskriptif**

# %%
df.describe(include='all')
# Out:
#            ProductID ProductCategory ProductBrand  ProductPrice  CustomerAge  \
# count    9000.000000            9000         9000   9000.000000  9000.000000
# unique           NaN               5            5           NaN          NaN
# top              NaN         Laptops      Samsung           NaN          NaN
# freq             NaN            1842         1854           NaN          NaN
# mean    10373.500000             NaN          NaN   1527.429195    43.347000
# std      2598.220545             NaN          NaN    829.900898    15.055084
# min      5874.000000             NaN          NaN    100.376358    18.000000
# 25%      8123.750000             NaN          NaN    809.165014    30.000000
# 50%     10373.500000             NaN          NaN   1513.024577    43.000000
# 75%     12623.250000             NaN          NaN   2244.415520    56.000000
# max     14873.000000             NaN          NaN   2999.852253    69.000000
#
# ...

# %% [markdown]
# 1. Count (Kelengkapan Data)
# Berdasarkan data, total baris transaksi adalah 9.000. Maka dapat disimpulkan:
#
# Tidak ada data yang hilang pada setiap kolom (seluruh kolom berisi 9.000 data lengkap).
#
# Kesimpulan: Seluruh kolom tidak mengandung missing values, sehingga dataset sudah lengkap dan siap digunakan untuk analisis lebih lanjut.
#
# ---
#
# 2. Mean vs Median (Distribusi Data)
# Kolom ProductPrice
#
# Mean = 1527,43
#
# Median (50%) = 1513,02
#
# Nilai rata-rata sangat mendekati median, menunjukkan distribusi harga produk yang relatif simetris.
#
# Kolom CustomerAge
#
# Mean = 43,35
#
# Median (50%) = 43,00
#
# Rata-rata yang hampir sama dengan median menandakan distribusi usia pelanggan cukup merata tanpa perbedaan ekstrem.
#
# Kolom PurchaseFrequency
#
# Mean = 10,05
#
# Median (50%) = 10,00
#
# Perbedaan yang sangat tipis menunjukkan distribusi frekuensi pembelian yang stabil dan seimbang.
#
# Kesimpulan: Secara keseluruhan, data numerik pada dataset ini cenderung berdistribusi normal/simetris dan tidak menunjukkan skewness yang signifikan.
#
# 3. Min dan Max (Validasi Logika)
# ProductPrice
#
# Min = 100,38
#
# Max = 2999,85
#
# CustomerAge
#
# Min = 18
#
# Max = 69
#
# CustomerSatisfaction
#
# Min = 1
#
# Max = 5
#
# Kesimpulan:
#
# Rentang ProductPrice (100 hingga 2.999) menunjukkan variasi harga yang luas, mencakup produk ekonomis hingga premium.
#
# Rentang Usia (18–69 tahun) sangat logis untuk target konsumen dewasa.
#
# Nilai Kepuasan berada dalam skala normal 1–5, sehingga tidak ada indikasi kesalahan input data.
#
# 4. Standar Deviasi (std) - Variabilitas Data
# ProductPrice
#
# Mean = 1527,43
#
# Std = 829,90
#
# PurchaseFrequency
#
# Mean = 10,05
#
# Std = 5,46
#
# Kesimpulan:
#
# Pada kolom ProductPrice, nilai standar deviasi yang besar menunjukkan variasi harga produk yang cukup lebar di dalam katalog.
#
# Pada kolom PurchaseFrequency, standar deviasi sebesar 5,46 mengindikasikan adanya perbedaan yang cukup kontras antara pelanggan jarang (skala rendah) dan pelanggan setia (skala tinggi).

# %% [markdown]
# # **Verifikasi Kualitas Data**

# %% [markdown]
# ## **Data Type Check**

# %% [markdown]
# Kita akan mengecek tipe data dari setiap kolom apakah sudah sesuai atau tidak. Agar insight serta visualisasi yang akan kita buat menjadi akurat.
#
# Dan dapat dilihat dibawah ini, seluruh kolom sudah memiliki tipe data yang sesuai dengan jenis datanya, sehingga tidak perlu dilakukan konversi tipe data.

# %%
df.dtypes
# Out:
# ProductID                 int64
# ProductCategory          object
# ProductBrand             object
# ProductPrice            float64
# CustomerAge               int64
# CustomerGender            int64
# PurchaseFrequency         int64
# CustomerSatisfaction      int64
# PurchaseIntent            int64
# dtype: object

# %% [markdown]
# ## **Inconsisten Values**

# %% [markdown]
# Pada tahap ini, kita perlu mengecek kekonsistenan data, contoh nya dalam penulisan. Hal ini dilakukan agar data tidak terduplikat dengan baris yang sebenarnya sama akan tetapi bisa terduplikat karena tidak konsisten.
#
# Setelah dicek, Saya tidak menemukan data yang tidak konsisten, yang menandakan data ini bersih dari Inconsistent Values,

# %% [markdown]
# ## **Missing Values**

# %% [markdown]
# Pada tahap ini, kita akan melihat seberapa banyak data yang hilang pada seluruh kolom. Dan terlihat bahwa:
#
# Tidak terdapat kolom yang memiliki missing values (0%).
#
# Semua data tidak yang hilang yang menandakan data bersih dari Missing Values.

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                       Null Ratio in %
# ProductID                         0.0
# ProductCategory                   0.0
# ProductBrand                      0.0
# ProductPrice                      0.0
# CustomerAge                       0.0
# CustomerGender                    0.0
# PurchaseFrequency                 0.0
# CustomerSatisfaction              0.0
# PurchaseIntent                    0.0

# %% [markdown]
# ## **Duplicated Values**

# %% [markdown]
# Pada tahap ini, kita akan mengecek duplikasi pada dataset. Hal ini dilakukan agar dataset memiliki insight dan hasil yang bersih.

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ProductID, ProductCategory, ProductBrand, ProductPrice, CustomerAge, CustomerGender, PurchaseFrequency, CustomerSatisfaction, PurchaseIntent]
# Index: []

# %% [markdown]
# Terlihat pada dataset ini tidak ada duplikasi. Maka hal ini tidak perlu ditangani, namun jika ingin menangani anda dapat mengetikkan
#
# df = df.drop_duplicates()

# %% [markdown]
# ## **Outliers Values**

# %% [markdown]
# Pada tahap ini, kita akan melihat nilai ekstrem (outliers) pada kolom yang bertipe data numerik. Hal ini dilakukan agar mendapatkan insight yang akurat sehingga dapat memperkuat analisis dan model yang akan kita bangun nantinya.
#
# Setelah di cek dat ini bersih dari Outliers, yang menandakan kita tidak perlu membersihkan data ini dari Outliers.

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

#Dataframe dari list hasil

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

#Tampilkan dataframe

display(results_df)
# Out:
# Kolom                 Persentase Outliers
# ProductID                             0.0
# ProductPrice                          0.0
# CustomerAge                           0.0
# CustomerGender                        0.0
# PurchaseFrequency                     0.0
# CustomerSatisfaction                  0.0
# PurchaseIntent                        0.0

# %% [markdown]
# #**Eksplorasi Data EDA**

# %% [markdown]
# ## **Comparison(Perbandingan)**

# %% [markdown]
# Aktivitas: Membandingkan jumlah barang yang laku sesuai umur.
#
# Tujuan: Mengidentifikasi kategori produk mana yang memberikan kontribusi pendapatan terbesar dan membandingkan performa antar kategori secara langsung.
#
# Visualisasi: Bar Chart (Grafik Batang).

# %%
penjualan_category = df.groupby('ProductBrand')['CustomerAge'].sum().sort_values(ascending=False)

plt.figure(figsize=(10,6))

sns.barplot(x=penjualan_category.index, y=penjualan_category.values, palette='viridis', hue=penjualan_category.index, legend=False)
plt.title('Total Akumulasi Umur Pelanggan per Brand Produk')
plt.xlabel('Brand Product')
plt.ylabel('Umur')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Insight
#
# 1. Dominasi Samsung: Samsung memimpin dengan akumulasi umur pelanggan tertinggi (mendekati 80.000). Ini menunjukkan bahwa basis pelanggan Samsung kemungkinan besar adalah yang paling besar atau terdiri dari pelanggan yang sudah setia dalam waktu lama.
# 2. Distribusi yang Merata: Tidak ada perbedaan yang sangat jomplang antar brand. Kelima kategori (Samsung, HP, Sony, Other Brands, dan Apple) semuanya berada di kisaran akumulasi umur 75.000 hingga 80.000.
# 3. Apple di Posisi Terendah: Meskipun Apple adalah brand premium, secara akumulasi umur pelanggan dalam dataset ini, mereka berada di posisi paling bawah. Ini bisa berarti jumlah penggunanya lebih sedikit dibanding yang lain, atau banyak pengguna baru (umur berlangganan masih pendek).
# 4. Potensi "Other Brands": Kategori "Other Brands" memiliki akumulasi yang hampir menyamai brand besar seperti Sony. Ini menandakan pasar produk alternatif cukup kuat.
#
# Action
#
# 1. Samsung
#
# a. Loyalty Program: Karena akumulasi umurnya paling tinggi, fokuslah pada program retensi. Berikan apresiasi kepada pelanggan lama agar mereka tidak pindah ke kompetitor.
#
# b. Upselling: Manfaatkan basis pelanggan yang besar ini untuk menawarkan produk flagship terbaru.
#
# 2. Apple
#
# a. Acquisition Campaign: Karena akumulasinya paling rendah, Apple perlu kampanye pemasaran yang lebih agresif untuk menarik pengguna baru atau meningkatkan penetrasi pasar.
#
# b. Analisis Churn: Periksa apakah angka yang rendah ini disebabkan oleh pelanggan yang cepat berhenti menggunakan produk (churn) atau memang volume penjualannya yang lebih kecil.
#
# 3. Brand Lain ( HP & Sony )
#
# a. Competitive Positioning: Karena posisinya di tengah, mereka harus mencari nilai unik (USP) agar tidak tergerus oleh dominasi Samsung atau daya tarik Apple.
#
# 4. Perbaikan Analisis Data
#
# a. Gunakan Rata-rata (Mean): Total akumulasi umur bisa bias jika jumlah pelanggan antar brand berbeda jauh. Disarankan untuk membuat grafik tambahan menggunakan rata-rata umur pelanggan (.mean()) untuk melihat profil demografi usia pengguna sebenarnya di tiap brand.

# %% [markdown]
# ## **Composition(Komposisi)**

# %% [markdown]
# Aktivitas :Melihat proporsi atau persentase jenis produk dan umur customer.
#
# Tujuan: Mengetahui kategori produk mana yang paling mendominasi total pembelian pelanggan secara keseluruhan.
#
# Visualisasi: Pie Chart (Grafik Lingkaran).

# %%
purchase_by_category = df.groupby('ProductCategory')['CustomerAge'].sum().sort_values(ascending=False)
purchase_by_category_top3 = purchase_by_category.head(3)

plt.figure(figsize=(10, 8))
purchase_by_category_top3.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Proporsi Total Umur Pelanggan pada 3 Kategori Produk Teratas')
plt.ylabel('')
plt.axis('equal')
plt.show()

# %% [markdown]
# Insight
#
# 1. Distribusi Pasar yang Sangat Merata: Ketiga kategori produk (Smartphones, Smart Watches, dan Laptops) memiliki proporsi yang hampir identik dalam hal kontribusi total umur pelanggan.
#
# Smartphones: 33.5%
#
# Smart Watches: 33.5%
#
# Laptops: 33.0%
#
# 2. Keseimbangan Demografis: Total akumulasi umur pelanggan pada ketiga kategori ini sangat seimbang. Ini menunjukkan bahwa basis pelanggan Anda tidak didominasi oleh satu kategori produk saja; ketiga kategori ini memiliki daya tarik yang sama kuatnya dalam menyerap segmen usia pelanggan.
#
# 3. Potensi "Cross-Selling" Tinggi: Karena proporsinya hampir sama besar ($1/3$ untuk masing-masing), kemungkinan besar pelanggan yang membeli Laptop juga memiliki ketertarikan yang setara terhadap Smartphone atau Smart Watch, atau sebaliknya.
#
# Action
#
# 1. Bundling Strategis: Mengingat proporsinya hampir sama, Anda dapat membuat paket "Product Ecosystem". Misalnya, bundel Smart Watch dengan Smartphone karena keduanya memiliki kontribusi data pelanggan yang identik (33.5%).
#
# 2. Personalisasi Marketing berdasarkan Usia: Karena data yang diolah adalah CustomerAge, lakukan analisis lebih lanjut (seperti Mean Age atau Age Grouping). Jika rata-rata usia di kategori Laptop lebih tinggi, sesuaikan gaya bahasa iklan Anda menjadi lebih profesional, sementara untuk Smart Watches bisa lebih mengarah ke gaya hidup aktif.
#
# 3. Loyalty Program Terintegrasi: Jangan membatasi program loyalitas hanya pada satu kategori. Buatlah poin yang dapat dikumpulkan dan digunakan di ketiga kategori ini untuk menjaga keseimbangan pasar yang sudah sehat ini.
#
# 4. Uji Penetrasi Pasar Laptop: Kategori Laptop sedikit tertinggal (selisih 0.5%). Anda bisa memberikan promo kecil atau cicilan khusus untuk kategori ini agar kontribusinya setara dengan dua kategori lainnya.

# %% [markdown]
# ## **Distribution(Distribusi)**

# %% [markdown]
# Aktivitas: Menganalisis penyebaran umur customer..
#
# Tujuan: Melihat apakah mayoritas transaksi bernilai kecil atau besar, serta mendeteksi adanya kecondongan (skewness) dalam data pembelian pelanggan.
#
# Visualisasi: Histogram.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['CustomerAge'], bins=20, kde=True)
plt.title('Distribusi Umur Pelanggan')
plt.xlabel('Customer Age')
plt.ylabel('Frekuensi')
plt.show()

# %% [markdown]
# Insight
# 1. Distribusi Seragam (Uniform Distribution): Grafik menunjukkan bahwa jumlah pelanggan tersebar cukup merata di berbagai rentang usia, mulai dari sekitar 18 hingga 70 tahun. Tidak ada satu kelompok umur yang mendominasi secara ekstrem.
# 2. Kehadiran Semua Kelompok Usia: Bisnis Anda memiliki daya tarik yang luas, mencakup Gen Z, Millennials, Gen X, hingga Baby Boomers. Ini menandakan produk atau layanan Anda bersifat umum (general).
# 3. Stabilitas Volume: Setiap bar (bin) berada di kisaran frekuensi 300 hingga 550. Meskipun ada fluktuasi kecil (misalnya sedikit penurunan di usia 30-an awal dan pertengahan 50-an), secara keseluruhan basis pelanggan Anda sangat stabil lintas generasi.
# 4. KDE (Kernel Density Estimate): Garis biru yang relatif datar di bagian atas mengonfirmasi bahwa kepadatan populasi pelanggan tidak memiliki "puncak" tunggal yang tajam.
#
# Action
# 1. Segmentasi Pemasaran
#
# a. Usia Muda (18-30): Fokus pada platform media sosial (TikTok/Instagram) dengan gaya bahasa yang tren dan visual yang dinamis.
#
# b. Usia Senior (50-70): Gunakan saluran komunikasi yang lebih tradisional atau email marketing dengan fokus pada kenyamanan, kualitas, dan layanan purna jual.
#
# 2. Analisis Nilai Pelanggan
#
# a. Lakukan cross-check data: "Apakah pelanggan umur 20-an belanja lebih sering, atau pelanggan umur 50-an yang belanja dalam jumlah besar (ticket size tinggi)?
#
# b. Fokuskan anggaran iklan pada segmen yang memiliki Customer Lifetime Value (CLV) tertinggi.
#
# 3. Penyesuaian Produk/Layanan
#
# a. Pastikan antarmuka (UI/UX) aplikasi atau toko fisik Anda ramah untuk semua umur (misalnya: ukuran font yang jelas untuk lansia, namun tetap modern untuk anak muda).
#
# 4. Strategi Retensi
#
# a. Karena distribusi umur merata, buatlah program loyalitas yang fleksibel. Misalnya, reward yang bisa dipilih (voucher belanja untuk yang muda, atau layanan prioritas/diskon kesehatan untuk yang senior).

# %% [markdown]
# ## **Relationship(Hubungan)**

# %% [markdown]
#   Aktivitas : Menganalisis korelasi antara nilai penjualan (Sales) dengan keuntungan (Profit).
#
# Tujuan: Mengetahui apakah pembelian dengan nominal yang lebih tinggi cenderung mendapatkan rating yang lebih baik, serta melihat kekuatan hubungan antara nilai transaksi dan kepuasan pelanggan.
#
# Visualisasi: Heatmap

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data=df[['CustomerAge', 'PurchaseFrequency']].corr(),
annot=True,
cmap='viridis',
fmt='.2f')
plt.title('Proporsi Akumulasi Umur Pelanggan per Kategori')
plt.show()

# %% [markdown]
# Insight
# 1. Nilai Korelasi Sangat Lemah (0.01): Angka 0.01 menunjukkan bahwa hampir tidak ada hubungan linear antara umur pelanggan dengan seberapa sering mereka berbelanja. Secara statistik, nilai ini mendekati nol.
# 2. Kemandirian Variabel: Ini berarti kamu tidak bisa memprediksi frekuensi belanja seseorang hanya dengan melihat usianya. Pelanggan muda (misal: Gen Z) dan pelanggan tua (misal: Boomers) memiliki pola frekuensi belanja yang serupa atau sangat acak satu sama lain.
# 3. Distribusi Merata: Produk atau layanan kamu nampaknya dibutuhkan oleh semua rentang usia secara merata, atau faktor yang mendorong orang untuk belanja berulang kali bukanlah faktor demografis usia, melainkan faktor lain (seperti harga, kualitas, atau kebutuhan mendesak).
#
# Action
# 1. Berhenti Melakukan Segmentasi Berbasis Usia untuk Loyalitas: Jangan membuat program loyalitas yang hanya menargetkan umur tertentu (misal: "Diskon khusus lansia agar rajin belanja"), karena data menunjukkan usia tidak menjamin loyalitas.
# 2. Cari Variabel Penggerak Lain: Lakukan analisis korelasi ulang dengan variabel lain yang mungkin lebih berpengaruh terhadap frekuensi pembelian, seperti:
#
# Income (Pendapatan)
#
# Distance to Store (Jarak ke toko)
#
# Discounts Applied (Penggunaan promo)
#
# Product Category (Kategori produk yang dibeli)
# 3. Strategi Pemasaran Inklusif: Karena frekuensi belanja merata di segala usia, gunakan pesan kampanye yang bersifat universal daripada pesan yang terlalu spesifik pada satu kelompok umur.
# 4. Fokus pada RFM Analysis: Daripada melihat Age, sebaiknya gunakan analisis Recency, Frequency, Monetary (RFM) untuk mengelompokkan pelanggan berdasarkan perilaku belanja nyata mereka.

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# ## **Mengecek Tipe Data**

# %%
df.dtypes
# Out:
# ProductID                 int64
# ProductCategory          object
# ProductBrand             object
# ProductPrice            float64
# CustomerAge               int64
# CustomerGender            int64
# PurchaseFrequency         int64
# CustomerSatisfaction      int64
# PurchaseIntent            int64
# dtype: object

# %% [markdown]
# Menurut saya, kode disini sudah benar dan cocok. Jadi tidak ada yang perlu diganti.

# %% [markdown]
# ## **Mengidentifikasi Inconsistent Values**

# %%
print(df['ProductCategory'].unique())
# Out:
# ['Smartphones' 'Smart Watches' 'Tablets' 'Laptops' 'Headphones']

# %%
print(df['ProductBrand'].unique())
# Out:
# ['Other Brands' 'Samsung' 'Sony' 'HP' 'Apple']

# %%
print(df['ProductPrice'].unique())
# Out:
# [ 312.94966811  980.38940432 2606.71829284 ... 2887.36959713 1490.45396391
#  2315.58308746]

# %%
df['ProductPrice'] = df['ProductPrice'].round().astype(int)

# %%
print(df['ProductPrice'].unique())
# Out:
# [ 313  980 2607 ... 1775 1520 1490]

# %%
print(df['CustomerAge'].unique())
# Out:
# [18 35 63 57 37 26 19 66 20 38 48 62 54 33 29 28 43 58 34 65 67 23 61 64
#  55 56 42 39 50 52 40 41 30 47 60 21 49 27 51 25 69 44 24 22 53 68 46 45
#  31 32 36 59]

# %%
print(df['CustomerGender'].unique())
# Out:
# [0 1]

# %%
print(df['PurchaseFrequency'].unique())
# Out:
# [ 2  7  1 10 17  8  5 12  3 14 16  4 18 15  9 19  6 11 13]

# %%
print(df['CustomerSatisfaction'].unique())
# Out:
# [1 2 5 3 4]

# %%
print(df['PurchaseIntent'].unique())
# Out:
# [0 1]

# %% [markdown]
# Dari hasil analisis saya:
#
#  1. ProductCategory |
# Pada data ini, sudah bersih dari Inconsistent Values, karena tidak ada pengulangan kata, maupun nomor anomali yang muncul.
#
# 2. ProductBrand |
# Pada data ini, sudah bersih dari Inconsistent Values, karena tidak ada pengulangan kata dengan tulisan yang berbeda, tidak ada nomor anomali yang muncul, dan tidak ada kata selain nama brand.
#
# 3. ProductPrice |
# Sebenarnya di data ini bisa dibilang tidak ada Inconsistent Values, namun ini sangat tidak wajar jika diperuntukkan sebagai Harga Produk. Maka saya ubah ke integer karena tipe ata ini, relevan untuk pecahan rupiah. ( Data Construction )
#
# 4. CustomerAge |
# Pada data ini, sudah bersih dari Inconsistent Values, karena semua angka yang keluar masih masuk akal dengan umur manusia, dan tidak ada terselip data yang anomali.
#
# 5. CustomerGender |
# Pada data ini sebenarnya sudah bersih dari Inconsistent Values, cuma kurag menjelaskan gender dari para pembeli.
#
# 6. CustomerFrequency |
# Ini sudah konsisten karena yang keluar integer dan biasanya frekuensi pembelian biasanya dihitung dalam jumlah bilangan cacah.
#
# 7. CustomerSatisfaction |
# Ini sudah konsisten, karena yang keluar full integer dan tidak ada data anomali yang keluar.
#
# 8. PurchaseIntent |
# Ini juga konsisten yang keluar hanya angka dan tidak ada data anomali

# %% [markdown]
# ## **Mengidentifikasi Missing Values.**

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio in %'])
# Out:
#                       Null Ratio in %
# ProductID                         0.0
# ProductCategory                   0.0
# ProductBrand                      0.0
# ProductPrice                      0.0
# CustomerAge                       0.0
# CustomerGender                    0.0
# PurchaseFrequency                 0.0
# CustomerSatisfaction              0.0
# PurchaseIntent                    0.0

# %% [markdown]
# Berdasarkan hasil data menunjukkan angka 0.0. Ini berarti setiap baris dalam dataset kamu telah terisi lengkap, dan tidak ada satu pun data yang kosong atau bernilai null di semua variabel tersebut.

# %% [markdown]
# ## **Mengidentifikasi Duplicated Values.**

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ProductID, ProductCategory, ProductBrand, ProductPrice, CustomerAge, CustomerGender, PurchaseFrequency, CustomerSatisfaction, PurchaseIntent]
# Index: []

# %% [markdown]
# Aman dari Duplicated Values karena tidak ada data ganda.
#
# Jika ada, kita bisa menggunakan kode df = df.drop_duplicates() untuk memperbaiki data dari Duplicated Values.

# %% [markdown]
# ## **Mengidentifikasi Outliers**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

#Dataframe dari list hasil

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

#Tampilkan dataframe

display(results_df)
# Out:
# Kolom                 Persentase Outliers
# ProductID                             0.0
# ProductPrice                          0.0
# CustomerAge                           0.0
# CustomerGender                        0.0
# PurchaseFrequency                     0.0
# CustomerSatisfaction                  0.0
# PurchaseIntent                        0.0

# %% [markdown]
# Berdasarkan hasil pengecekan pada tabel persentase pencilan, data ini dinyatakan tidak memiliki outliers karena seluruh variabel menunjukkan angka 0.0.

# %% [markdown]
# # **Data Reduction**

# %%
df_reduced = df.drop(columns=['ProductID'])
df_reduced.head()
# Out:
#   ProductCategory  ProductBrand  ProductPrice  CustomerAge  CustomerGender  \
# 0     Smartphones  Other Brands           313           18               0
# 1   Smart Watches       Samsung           980           35               1
# 2         Tablets       Samsung          2607           63               0
# 3     Smartphones       Samsung           870           63               1
# 4         Tablets          Sony          1799           57               0
#
#    PurchaseFrequency  CustomerSatisfaction  PurchaseIntent
# 0                  2                     1               0
# 1                  7                     2               1
# 2                  1                     5               1
# 3                 10                     3               1
# 4                 17                     3               0

# %% [markdown]
# Alasan utama ProductID dihapus dalam proses reduksi data adalah karena kolom tersebut merupakan Unique Identifier yang tidak memiliki nilai korelasi atau pola sebab-akibat terhadap target analisis (misalnya PurchaseIntent).
#
# Unique Identifier (Identitas Unik) adalah label atau kode khusus yang diberikan kepada setiap baris data untuk memastikan tidak ada dua data yang tertukar.

# %% [markdown]
# # **Construct Data**

# %% [markdown]
# Construct Data sudah saya terapkan di data ini pada bagian ProductPrice.

# %% [markdown]
# # **Visualisasi Data**

# %% [markdown]
# ## **Bar Chart**

# %%
# Bar Chart (Matplotlib)
top5negara = df['ProductBrand'].value_counts().head(5).sort_values(ascending=False) # head() jumlah yang mau ditampilkan & Urutan

plt.figure(figsize=(25, 20)) # Ukuran
plt.bar(top5negara.index, top5negara.values, color='skyblue') # color warna
plt.xlabel('Brand') # keterangan X label
plt.ylabel('Jumlah') # keterangan y label
plt.title('Top 5 Brand dengan penjualan terbanyak') # Judul
plt.xticks(rotation=45, ha='right') # rotasi teks
plt.tight_layout()
plt.show()

# %% [markdown]
# Insight:
# 1. Kelima brand memiliki performa yang sangat kompetitif. Tidak ada satu brand yang mendominasi secara ekstrem; selisih antara peringkat ke-1 (sekitar 1.850 unit) dan peringkat ke-5 (sekitar 1.760 unit) tergolong tipis.
# 2. Karena angka penjualannya hampir sejajar di angka 1.750–1.850, ini menunjukkan bahwa pasar memiliki minat yang stabil terhadap lima brand besar ini. Pelanggan tidak hanya terpaku pada satu merk saja.
# 3. Seluruh top 5 brand berhasil menembus angka penjualan di atas 1.750. Ini menandakan kategori produk tersebut memiliki permintaan (demand) yang kuat secara keseluruhan.
#
# Action:
# 1. Karena selisihnya tipis, brand di posisi pertama harus memperkuat customer loyalty (misalnya dengan program loyalty member) agar posisinya tidak segera disalip oleh brand kedua.
# 2. Brand di posisi bawah bisa diberikan sedikit dorongan berupa promo paket (bundling) atau diskon terbatas. Dengan sedikit stimulus, mereka memiliki potensi besar untuk naik ke peringkat pertama karena selisih unit yang kecil.
# 3. Mengingat kelima brand ini adalah top sellers, pastikan ketersediaan stok (safety stock) selalu terjaga. Kehabisan stok pada salah satu brand ini akan langsung memberikan keuntungan besar bagi kompetitornya karena konsumen kemungkinan besar bersedia beralih ke brand lain di daftar ini.
# 4. Perlu dilakukan pengecekan apakah brand dengan penjualan terbanyak (nomor 1) juga memberikan profit margin tertinggi. Jika brand di posisi 5 ternyata memiliki margin keuntungan lebih besar, maka fokus pemasaran sebaiknya dialihkan untuk mendorong brand nomor 5 tersebut.

# %% [markdown]
# ## **Pie Chart ( 1 kolom )**

# %%
# Pie Chart (Matplotlib) (HANYA 1 KOLOM)
plt.figure(figsize=(10, 6)) # ukuran
plt.pie(df['CustomerGender'].value_counts(), labels=df['CustomerGender'].value_counts().index, autopct='%1.1f%%', colors=['lightcoral', 'lightblue', 'lightgreen', 'gold']) # colors (warna)
plt.title('Pembelian sesuai gender') # Judul
plt.show()

# %% [markdown]
# Insight:
# 1. Selisih hanya sebesar 1,8% menunjukkan bahwa data ini sangat "balance".
# 2. Jika data ini benar, berarti perilaku pembelian tidak dipengaruhi oleh gender. Pria dan wanita (asumsi untuk label 0 dan 1) melakukan pembelian dalam proporsi yang hampir sama persis.
#
# Action:
# 1. Karena distribusi pembelian hampir 50:50, hindari kampanye pemasaran yang terlalu spesifik pada satu gender saja. Gunakan pesan yang bersifat universal atau inklusif agar dapat menjangkau seluruh basis pelanggan secara efektif.
# 2.

# %% [markdown]
# ## **Pie Chart ( berdasarkan kolom lain )**

# %%
# Pie Chart (Matplotlib) (Berdasarkan Kolom Lain)
sales_by_category = df.groupby('ProductCategory')['PurchaseFrequency'].sum().sort_values(ascending=False)
sales_by_category_top3 = sales_by_category.head(3)

plt.figure(figsize=(10, 8)) # Ukuran
sales_by_category_top3.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Proporsi 3 Jenis gadget yang paling laku') # Judul
plt.ylabel('') # Keterangan Y
plt.axis('equal')
plt.show()

# %% [markdown]
# Insight:
# 1. Proporsi penjualan antara Laptops (33,8%), Smartphones (33,4%), dan Headphones (32,7%) hampir identik. Hal ini menunjukkan bahwa pasar gadget Anda tidak didominasi oleh satu jenis produk saja; ketiga kategori tersebut merupakan tulang punggung bisnis yang sama kuatnya.
#
# Insight:
# 1. Karena proporsi Laptops, Smartphones, dan Headphones sangat mirip, buatlah paket bundling. Misalnya, setiap pembelian Laptop atau Smartphone, berikan penawaran khusus untuk Headphones. Ini berpotensi menaikkan total nilai transaksi karena minat pelanggan pada ketiga item tersebut sudah merata.
# 2. Berhenti mengotak-ngotakkan promosi berdasarkan gender atau kategori tertentu secara berlebihan. Gunakan kampanye pemasaran yang bersifat universal karena data menunjukkan audiens Anda terbagi rata secara demografis maupun minat kategori.
# 3. Pastikan ketersediaan unit untuk ketiga jenis gadget selalu terjaga dalam jumlah yang mirip. Kekosongan stok pada satu jenis gadget (misal: Laptops) akan langsung kehilangan peluang di 1/3 total potensi pasar Anda.

# %%
df['ProductPrice'] = pd.to_numeric(df['ProductPrice'], errors='coerce')
df['PurchaseFrequency'] = pd.to_numeric(df['PurchaseFrequency'], errors='coerce')
df['PurchaseIntent'] = pd.to_numeric(df['PurchaseIntent'], errors='coerce')
df['CustomerSatisfaction'] = pd.to_numeric(df['CustomerSatisfaction'], errors='coerce')

# %% [markdown]
# ## **Histogram**

# %%
# Histogram (Matplotlib): Distribusi Penjualan
plt.figure(figsize=(10, 5))
plt.hist(df['ProductBrand'], bins=10, color='maroon', edgecolor='black')
plt.title('Brand yang paling laku')
plt.show()

# %% [markdown]
# Insight:
# 1. Penjualan antara Laptops (33,8%), Smartphones (33,4%), dan Headphones (32,7%) hampir terbagi rata secara sempurna. Hal ini menandakan bisnis Anda tidak memiliki ketergantungan pada satu jenis produk saja.
# 2. Samsung memimpin sebagai brand paling laku, diikuti rapat oleh HP, Sony, Other Brands, dan Apple. Selisih antar brand sangat kecil, menunjukkan loyalitas pelanggan di pasar ini sangat kompetitif dan mudah beralih (low switching cost).
# 3. Distribusi gender pembeli menunjukkan angka 50,9% (Grup 1) dan 49,1% (Grup 0). Angka ini identik dengan distribusi kategori produk, yang mengindikasikan bahwa baik pria maupun wanita memiliki minat dan daya beli yang sama kuatnya terhadap gadget yang Anda tawarkan.
#
# Action:
# 1. Karena proporsi laptop, ponsel, dan headphone sangat seimbang, buatlah paket "Product Ecosystem". Misalnya, bundel laptop HP dengan headphone Sony, atau smartphone Samsung dengan headphone. Ini akan meningkatkan Average Order Value (AOV) karena minat konsumen pada ketiga kategori tersebut sudah ada secara alami.
# 2. Hentikan segmentasi iklan yang terlalu kaku berdasarkan gender. Karena data pembeli hampir 50:50, gunakan konten visual yang netral atau inklusif yang menonjolkan fungsi gadget untuk produktivitas dan gaya hidup tanpa memandang gender.
# 3. Pertahankan stok yang berimbang. Mengingat tidak ada produk yang "lambat" (semuanya di kisaran 32-33%), kekurangan stok pada satu kategori akan langsung membuang sepertiga potensi pendapatan Anda.

# %% [markdown]
# ## **Box Plot**

# %%
# Identifikasi 5 negara teratas berdasarkan jumlah entri
top5negara = df['ProductBrand'].value_counts().head(5).index

# Filter DataFrame untuk hanya menyertakan 5 negara teratas
df_top5_countries = df[df['ProductBrand'].isin(top5negara)]

plt.figure(figsize=(12, 7)) # Ukuran figure
df_top5_countries.boxplot(column='ProductPrice', by='ProductBrand', ax=plt.gca(), grid=False, patch_artist=True, medianprops=dict(color='red'))
plt.title('Distribusi Harga di Top5 Brand', fontsize=16) # Judul
plt.xlabel('Brand Produk', fontsize=12) # X Keterangan
plt.ylabel('Harga Produk', fontsize=12) # Y Keterangan
plt.xticks(rotation=45, ha='right')
plt.suptitle('') # Menghilangkan judul default dari boxplot.by
plt.tight_layout()
plt.show()

# %% [markdown]
# Insight:
# 1. Rata-rata harga (median - garis merah) di semua brand berada di kisaran yang mirip, yaitu sekitar 1500.
# 2. Tidak terlihat adanya outliers (titik di luar garis whisker), yang berarti brand-brand tersebut memiliki variasi produk dari kelas entry-level (harga mendekati 100) hingga high-end (harga mendekati 3000) secara merata.
# 3. Samsung memiliki median harga sedikit lebih tinggi dibanding yang lain.
#
# Action:
# 1. Karena rentang harganya sangat luas (100 - 3000), pastikan strategi pemasaran Anda menyasar berbagai kelas ekonomi.
# 2. Optimalkan stok pada rentang harga 1000 - 2200 (area kotak biru), karena di situlah mayoritas transaksi terjadi bagi semua brand.

# %% [markdown]
# ## **Scatter Plot**

# %% [markdown]
# Scatter Plot tidak relevan pada dataset ini.

# %% [markdown]
# ## **Heatmap**

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(data=df[['ProductPrice', 'CustomerAge', 'PurchaseFrequency', 'CustomerSatisfaction','PurchaseIntent']].corr(),
            annot=True,
            cmap='viridis',
            fmt='.2f')
plt.title('Korelasi antar Kolom')
plt.show()

# %% [markdown]
# Insight:
# 1. Keseimbangan Kategori: Penjualan antara Laptops (33,8%), Smartphones (33,4%), dan Headphones (32,7%) sangat seimbang, menunjukkan tidak ada ketergantungan pada satu jenis produk saja.
# 2. Samsung adalah brand dengan volume penjualan tertinggi, disusul oleh HP dan Sony, sementara Apple berada di posisi kelima.
# 3. Melalui box plot, terlihat bahwa median harga produk di semua brand (Apple, HP, Samsung, Sony) berada di kisaran yang sama (sekitar 1500), dengan rentang harga yang luas dari 100 hingga 3000.
#
# Action:
# 1. Karena minat pada ketiga kategori gadget hampir rata, buatlah paket bundling lintas kategori (misal: Beli Smartphone Samsung gratis Headphones) untuk meningkatkan total nilai transaksi.
# 2. Mengingat volume Apple paling rendah meskipun median harganya serupa dengan brand lain, perlu ditinjau apakah ketersediaan stok atau varian produk Apple di toko Anda perlu ditambah.

# %% [markdown]
# # **Menyimpan Dataset**

# %%
df.to_csv('Checkpoint 3 Andhika Fhariel', index=False)
